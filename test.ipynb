# %%
/Users/heng/arma/arma/arma.py
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from arma import ARMA
#
# ImportError: cannot import name 'ARMA' from 'arma' (/Users/heng/arma/arma/__init__.py)

# %%
from arma import ARMA
from arma import MA
from arma import AR

# %%
arma_model = ARMA(p=1, q=1,phi=[0.5],theta=[0.5],c=1.0,mu=0.0,sigma=1.0)
print(arma_model.c ,arma_model.mu,arma_model.sigma)# arrtibute
# Out:
# 1.0 0.0 1.0

# %%
arma_model.simulate()
arma_model.memory
# Out:
# array([3.18992101, 3.7896874 , 3.56278866, 2.71982827, 2.27343736,
#        3.3147635 , 3.36182919, 2.41144317, 2.0569451 , 0.64366603,
#        3.37516421, 2.62165349, 1.82347115, 2.60570251, 3.05625864,
#        2.34601899, 2.19823052, 1.90291259, 1.31338401, 0.09505672,
#        0.        ])

# %%
arma_model.noise_memory
# Out:
# array([-0.00578663,  0.60172788,  0.81313038,  0.77948827, -0.39275735,
#         0.01762593,  1.23244596, -0.15267671,  1.07129466, -0.67236516,
#         0.63206238,  0.86455017, -0.30926452, -0.34023117,  0.83560872,
#         0.09528085,  0.30324575, -0.11294306,  0.71832729, -0.90494328,
#         0.        ])

# %%
arma_model.plot()

# %%
arma_model.statistics()
# Out:
# 'Mean: 2.0000, Variance: 1.7500'

# %%
arma_model.save("file_name=arma_model.csv")
# Out:
# 'File saved as file_name=arma_model.csv'

# %%
from arma  import AR
import numpy as np  
from arma import ARMA   
from arma import MA 
import matplotlib.pyplot as plt

# %%
from arma import ARMA   
from arma import MA
from arma import AR
import numpy as np

# %%
arma_model = ARMA(p=2,q=2,phi=[0.5,0.2],theta=[0.5,0.3],c=1.0,mu=0.0,sigma=1.0)

# %%
np.random.seed(123)
arma_model.simulate(10)
# Out:
# array([-0.0856306 ,  1.41171484,  2.14469334,  1.28908781,  0.82662851,
#         2.58137982,  0.68147456,  0.71019195,  1.81486706,  1.68702586])

# %%
arma_model.memory
# Out:
# array([ 1.68702586,  1.81486706,  0.71019195,  0.68147456,  2.58137982,
#         0.82662851,  1.28908781,  2.14469334,  1.41171484, -0.0856306 ,
#         0.        ,  0.        ])

# %%
arma_model.noise_memory
# Out:
# array([-0.8667404 ,  1.26593626, -0.42891263, -2.42667924,  1.65143654,
#        -0.57860025, -1.50629471,  0.2829785 ,  0.99734545, -1.0856306 ,
#         0.        ,  0.        ])

# %%
arma_model.covariance(4)
# Out:
# 共變異數(lag 0):0.6300
# 共變異數(lag 1):0.2500
# 共變異數(lag 2):0.0000
# 共變異數(lag 3):0.0000
# 共變異數(lag 4):0.0000
# array([0.63, 0.25, 0.  , 0.  , 0.  ])

# %%
arma_model.statistics()
# Out:
# 'Mean: 3.3333, Variance: 1.9200'

# %%
arma_model.plot()

# %%
arma_model.save("arma_sim.csv")
# Out:
# 'File saved as arma_sim.csv'

# %% [markdown]
# - AR

# %%
from arma import AR
ar_model=AR(2,phi=[0.5,0.3],c=0,mu=0,sigma=1)

# %%
ar_model.simulate(10)
# Out:
# array([-0.67888615, -0.43415204,  1.07064776, -0.23382373, -0.2396995 ,
#        -0.62434814,  1.82184616,  2.91040473,  3.00581011,  2.76221287])

# %%
from arma import MA

# %%
ma_model=MA(q=2,theta=[0.5,0.3],c=0,mu=0,sigma=1)
ma_model.simulate(10)
# Out:
# array([ 0.46843912, -0.59693542,  0.88715829, -0.76544752, -2.32304066,
#        -0.350984  , -0.5204326 , -0.01579448, -1.02154133, -2.06253   ])

# %%
ma_model.plot()
